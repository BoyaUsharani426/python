# %% [markdown]
# Functions

# %%
def fun():
    print("Hello")#without calling func we don't get output

# %%
def fun():
    print("Hello")
fun() #call the function then we get output
# Out:
# Hello

# %%
def evenodd(x):
    if x%2==0:
        return 'even'
    else:
        return 'odd'
print(evenodd(7))
print(evenodd(10))
# Out:
# odd
# even

# %% [markdown]
# Types of Function Arguments

# %%
#1.Default Arguments:A default argument is a parameter that assumes a default value if a value is not provided in the function call for that argument.
def myfun(x,y=50):
    print('x:',x)
    print('y:',y)
myfun(20)
# Out:
# x: 20
# y: 50

# %%
#2.Keyword Arguments:In keyword arguments, values are passed by explicitly specifying the parameter names, so the order doesn’t matter.
def student(fname, lname):
    print(fname, lname)

student(fname='Geeks', lname='Practice')
student(lname='Practice', fname='Geeks')
# Out:
# Geeks Practice
# Geeks Practice

# %%
#3. Positional Arguments:In positional arguments, values are assigned to parameters based on their order in the function call.

# %%
def nameage(name,age):
    print('Hi,I am',name)
    print('My age is',age)
print('case 1:')    
nameage('suman',20)
print('\n case 2:')
nameage(20,'suman')
# Out:
# case 1:
# Hi,I am suman
# My age is 20
#
#  case 2:
# Hi,I am 20
# My age is suman

# %%
def greet():
    print('Welcome')
greet()
# Out:
# Welcome

# %%
def greet():
    print('Welcome')
greet()  

def greet():
    print('Welcome')
greet() 
 
def greet():
    print('Welcome')
greet()
# Out:
# Welcome
# Welcome
# Welcome

# %%
def greet():
    print('welcome')
greet()
greet()
greet()  
print()
# Out:
# welcome
# welcome
# welcome

# %%
def add(x,y,z):
    c=x+y
    print(c)
add(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2     c=x+y
#       3     print(c)
# ----> 4 add(2,3)
#
# TypeError: add() missing 1 required positional argument: 'z'

# %%
def greet():
    print('Welcome')
greet()  

def add(x,y):
    c=x+y
    print(c)
add(2,3)
# Out:
# Welcome
# 5

# %%
def greet():
    print('welcome')
def add(x,y):
    c=x+y
    print(c)
def sub(x,y):
    c=x-y
    print(c)
greet()
add(5,6)
sub(2,8)

greet()
add(10,20)
sub(50,100)
# Out:
# welcome
# 11
# -6
# welcome
# 30
# -50
# function

# %%
def add(x,y):
    c=x+y
    return c
def sub(x,y):
    c=x-y
    return c
result1=add(5,6)
result2=sub(2,8)
print(result1)
print(result2)

result3=add(10,20)
result4=sub(50,100)
print(result3)
print(result4)

print(type(result1))
print(type(result2))
print(type(result3))
print(type(result4))
# Out:
# 11
# -6
# 30
# -50
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
def add_sub(x,y):
    c=x+y
    d=x-y
    return c,d
result=add_sub(20,30)
print(result)
print(type(result))
# Out:
# (50, -10)
# <class 'tuple'>

# %%
def update():
    x=8
    return x
update()
# Out:
# 8

# %%
def update(x):
    x=8
    return x
update(8)
# Out:
# 8

# %%
def update(x):
    x=8
    return x
update(2)
# Out:
# 8

# %%
def update(x):
    x=8
    return x
a=2
print(update(a))
print(a)
# Out:
# 8
# 2

# %%
#function without arguments required nothing
#function with arguments divide into two parts
#1.Actual Arg
#2.Formal arg

# %%
def add(x,y):#formal Arg
    a=x+y
    return a
add(2,3)#Actual Arg

# %% [markdown]
# Pass by value and Pass by reference

# %%
# Function modifies the first element of list
def myFun(x):
    x[0] = 20

lst = [10, 11, 12, 13]
myFun(lst)
print(lst)   # list is modified

# Function tries to modify an integer
def myFun2(x):
    x = 20

a = 10
myFun2(a)
print(a)     # integer is not modified
# Out:
# [20, 11, 12, 13]
# 10

# %% [markdown]
# RECURSIVE FUNCTIONS:
# A recursive function is a function that calls itself to solve a problem. It is commonly used in mathematical and divide-and-conquer problems. Always include a base case to avoid infinite recursion.

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(4))
# Out:
# 24

# %%
def tail_fact(n, acc=1):
    # Base case
    if n == 0:
        return acc
    # Tail recursive call with an accumulator
    else:
        return tail_fact(n-1, acc * n)

def nontail_fact(n):
    # Base case
    if n == 1:
        return 1
    # Non-tail recursive call because the multiplication happens after the call
    else:
        return n * nontail_fact(n-1)

# Example usage
print(tail_fact(5))  
print(nontail_fact(5))
# Out:
# 120
# 120

# %% [markdown]
# lambda function

# %%
s1 = 'Python'
s2 = lambda func: func.upper()
print(s2(s1))
# Out:
# PYTHON

# %%
n = lambda x: "Positive" if x > 0 else "Negative" if x < 0 else "Zero"
print(n(5))   
print(n(-3))  
print(n(0))
# Out:
# Positive
# Negative
# Zero

# %%
li = [lambda arg=x: arg * 10 for x in range(1, 5)]
for i in li:
    print(i())
# Out:
# 10
# 20
# 30
# 40

# %%
calc = lambda x, y: (x + y, x * y)#perform multiple operations
res = calc(3, 4)
print(res)
# Out:
# (7, 12)

# %%
n = [1, 2, 3, 4, 5, 6]
even = filter(lambda x: x % 2 == 0, n)# filter out all the elements of a sequence
print(list(even))
# Out:
# [2, 4, 6]

# %%
a = [1, 2, 3, 4]
b = map(lambda x: x * 2, a)
print(list(b))
# Out:
# [2, 4, 6, 8]

# %%
from functools import reduce
a = [1, 2, 3, 4]
b = reduce(lambda x, y: x * y, a)
print(b)
# Out:
# 24

# %%
from functools import reduce
a = [1, 2, 3, 4]
b = reduce(lambda x, y: x * y, a)
print(b)

# %% [markdown]
# String Manuplications

# %%
s = """I am Learning
Python String"""
print(s)

s = '''I'm a 
Geek'''
print(s)
# Out:
# I am Learning
# Python String
# I'm a
# Geek

# %%
s = "Python"
for char in s:
    print(char)
# Out:
# P
# y
# t
# h
# o
# n

# %%
s = "python programming"
print(len(s))
# Out:
# 18

# %%
s = "Hello World"
print(s.upper())
print(s.lower())
# Out:
# HELLO WORLD
# hello world

# %%
s = "   coding  "
print(s.strip())  #removes leading and trailing whitespace from the string   

s = "Python is fun"
print(s.replace("fun", "awesome"))#replaces all occurrences of a specified substring with another
# Out:
# coding
# Python is awesome

# %%
s = "Hello "
print(s * 3)#Repeat multiple times
# Out:
# Hello Hello Hello

# %%
#concatinate two strings
s1 = "Hello"
s2 = "World"
print(s1 + " " + s2)
