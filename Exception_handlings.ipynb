# %% [markdown]
# Exception handlings in python
# - ERRORs are 3 type of errors -- COMPLILE TIME ERROR || LOGICAL ERROR || RUNTIME ERROR
# - if we print with wrong spelling & we working with if and we forget to columne those mistakes are syntatcticla error & those error are called as compile time error
# - when we add 2 + 3 = 4
# - code is compiled and also code gives the output but we got the wrong output then those type of error called as LOGICAL ERROR
# - code is compiled and no syntactical error . code not gives logical error as well
# - but some time user might give wrong input by user ( 10/2 - user entered 10 & 2 code will work)
# - when the user enter 6/0 then entry made by the user is called RUN TIME EROOR
# - usert getting error at run time those error called as run time

# %%
a=5
b=2
print(a/b)
print('bye')
# Out:
# 2.5
# bye

# %%
c = 3
d = 0
print(c/d)
print('bye')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 c = 3
#       2 d = 0
# ----> 3 print(c/d)
#       4 print('bye')
#
# ZeroDivisionError: division by zero

# %%
c = 3
d = 0
try:
    print(c/d)
except Exception:
    print('hey you can not print Zerodivision error')
print('bye')
# Out:
# hey you can not print Zerodivision error
# bye

# %%
c = 3
d = 3
try:
    print(c/d)
except Exception:
    print('hey you cannot divide Number by zero')

print('bye')
      # except blok will execute only when you entere the error
# Out:
# 1.0
# bye

# %%
# if i print the error message as well along with message 
c = 3
d = 0
try:
    print(c/d)
except Exception as e :
    print('hey you cannot divide Number by zero',  e)

print('bye')
# Out:
# hey you cannot divide Number by zero division by zero
# bye

# %%
# if i print the error message as well along with message 
c=3
d=3
try:
    print('resource open')# resource can be anything this can be file this can be database
    print(c/d)
    print('resource close')
except Exception as e:
    print('hey you cannot divide Number by zero as ',e)
# if you see the output then resource is open but resource is not closed hear at exception block
# Out:
# resource open
# 1.0
# resource close

# %%
c=3
d=3
try:
    print('resource open')
    print(c/d)
except Exception as e:
    print('hey you cannot divide Number by zero as ',e)
print('resource close')
# Out:
# resource open
# 1.0
# resource close

# %%
c=3
d=3
try:
    print('resource open')
    print(c/d)
except Exception as e:
    print('hey you cannot divide Number by zero as ',e)
    print('resource close')
finally:
    print('resource close')
# it does not matter about any block finally it will execute
# Out:
# resource open
# 1.0
# resource close

# %%
c=3
d=3
try:
    print('resource open')
    print(c/d)
    k=int(input('Enter the number:'))
    print(k)
except Exception as e:
    print('hey you cannot divide Number by zero as ',e)
    print('resource close')
finally:
    print('resource close')
# Out:
# resource open
# 1.0
# 5
# resource close

# %%
c=3
d=3
k=int(input('Enter the number:'))
print(k)
try:
    print('resource open')
    print(c/d)
except Exception as e:
    print('hey you cannot divide Number by zero as ',e)
    print('resource close')
finally:
    print('resource close')
# Out:
# 7
# resource open
# 1.0
# resource close

# %% [markdown]
# - so different type of error we have different names as well
# - what ever error it will come then EXCEPTION on top
# - 0 division error it is part of exception \ value error - part of the exception
# - exception can handle everything but you can be specific
# - i wanted to give common example if you have any disease regarding skin - dermatology, teeth- dentist
# headche - phycian similar way for different type of error we have different type of except block

# %%
c = 3
d = 3
  
try:
    print('resource open') # resource can be anything this can be file this can be database
    print(c/d)
    k = int(input('enter the number'))
    print(k)
 #hear we are trying handle zero division error 
except ZeroDivisionError as e :
    print('hey you cannot divide Number by zero',  e)   
    # hear we trying to handle value error
    
except ValueError as e:
    print('invalid input')
    # what happen the error which you dont know about it which are not is zero division error & values erro 
    # i mean if you go to dentist, skin specialist, finaly you go to the general physician
    # this exception can handle all other exception 
except Exception as e:
    print('something is wrrong..')
    

finally:
    print('resource closed')
# Out:
# resource open
# 1.0
# 7
# resource closed
