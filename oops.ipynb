# %% [markdown]
# OOP(Object Oriented Programming)

# %%
a = 5
print(type(a)) #inbuild class
# Out:
# <class 'int'>

# %%
class computer:
    def config():
        print('i5','8gb')
com1=computer()
print(type(com1))
# Out:
# <class '__main__.computer'>

# %%
class computer:
    def config():
        print('i5','8gb')
com1=computer()
computer.config()
# Out:
# i5 8gb

# %%
class computer:
    def config(self):
        print('i5','8gb')
com1=computer()
computer.config(com1)
# Out:
# i5 8gb

# %%
class computer:
    def config(self):
        print('i5','8gb')
com1=computer()
com2=computer()
computer.config(com1)
computer.config(com2)
# Out:
# i5 8gb
# i5 8gb

# %%
class computer:
    def config(self):
        print('i5','8gb')
com1=computer()
com2=computer()
computer.config(com1)
computer.config(com2)
com1.config()
com2.config()
# Out:
# i5 8gb
# i5 8gb
# i5 8gb
# i5 8gb

# %%
class computer:
    def config(self):
        print('i5','8gb')
com1=computer()
com2=computer()

com1.config()
com2.config()
# Out:
# i5 8gb
# i5 8gb

# %% [markdown]
# # __ init __ method in python
# - special method in oops

# %%
class computer:
    def __init__(self):
        print('python')
    def config(self):
        print('i5','8gb')
com1=computer()
com2=computer()

com1.config()
com2.config()
# Out:
# python
# python
# i5 8gb
# i5 8gb

# %%
class computer:
    def __init__(self):
        print('python')
    def config(self):
        print('i5','8gb')
com1=computer('i5',8)
com2=computer('intel 5',8)

com1.config()
com2.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       4     def config(self):
#       5         print('i5','8gb')
# ----> 6 com1=computer('i5',8)
#       7 com2=computer('intel 5',8)
#       9 com1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 3 were given

# %%
class computer:
    def __init__(self,cpu,ram):
        print('python')
    def config(self):
        print('i5','8gb')
com1=computer('i5',8)
com2=computer('intel 5',8)

com1.config()
com2.config()
# Out:
# python
# python
# i5 8gb
# i5 8gb

# %%
class computer:        
    
    def __init__(self,cpu,ram): # cpu & ram as argument
        self.cpu = cpu
        self.ram = ram 
    
    def config(self):     
        print('config is', self.cpu, self.ram)

com1 = computer('i5', 8)
com2 = computer('intel 5', 8)

com1.config() 
com2.config()
# Out:
# config is i5 8
# config is intel 5 8

# %%
class computer:
   
c1 = computer()
print(id(c1))
# Out:
#   Cell In[24], line 3
#     c1 = computer()
#     ^
# IndentationError: expected an indented block after class definition on line 1

# %%
class computer:
    pass
   
c1 = computer()
c2=computer()
print(id(c1))
print(id(c1))
# Out:
# 1586837299824
# 1586837299824

# %%
class student():
    def __init__(self):
        self.name='Priya'
        self.age=27
std1=student()
std2=student()
print(std1.name)
print(std2.age)
# Out:
# Priya
# 27

# %%
class computer:
    def __init__(self):
        self.name = 'prakash'
        self.age = 37

c1 = computer()
c2 = computer()

print(id(c1))
print(id(c2))

c1.name = 'kodi'
c1.age = 38

print(c1.name)
print(c1.age)
print(c2.name)
# Out:
# 1586837300160
# 1586843554256
# kodi
# 38
# prakash

# %%
class computer():
    def __init__(self):
        self.name='prakash'
        self.age=30
    def update(self):
        self.age=38
c1=computer()
c2=computer()
c1.name='kodi'
c1.age=27
c1.update()
print(c1.name)
print(c1.age)
print(c2.name)
print(c2.age)
# Out:
# kodi
# 38
# prakash
# 30

# %%
class computer():
    def __init__(self):
        self.name='prakash'
        self.age=30
    def update(self):
        self.age=38
c1=computer()
c2=computer()
if c1.compare(c2):
    print('they are same')
c1.update()
print(c1.name)
print(c1.age)
print(c2.name)
print(c2.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 9
#       7 c1=computer()
#       8 c2=computer()
# ----> 9 if c1.compare(c2):
#      10     print('they are same')
#      11 c1.update()
#
# AttributeError: 'computer' object has no attribute 'compare'

# %%
class computer:
    def __init__(self):
        self.name = 'prakash'
        self.age = 37
    
    def compare(self,other):  
        if self.age ==other.age:
            return True
        else:
            return False


c1 = computer()
c2 = computer()

print(id(c1))
print(id(c2))

if c1.compare(c2):
    print('they are same') 

print(c1.name)
print(c2.name)
# Out:
# 1357473802160
# 1357474652368
# they are same
# prakash
# prakash

# %%
class computer:
    def __init__(self):
        self.name = 'prakash'
        self.age = 37
    
    def compare(self,other):  
        if self.age ==other.age:
            return True
        else:
            return False


c1 = computer()
c1.age=30
c2 = computer()

print(id(c1))
print(id(c2))

if c1.compare(c2):
    print('they are same') 
else:
    print('they are different') 

print(c1.name)
print(c2.name)
# Out:
# 1357473802160
# 1357474652368
# they are different
# prakash
# prakash

# %%
class school():
    def __init__(self,m,s):
        self.maths_marks=m
        self.science_marks=s
c1=school(80,90)

# %%
class school():
    def __init__(self,m,s):
        self.maths_marks=m
        self.science_marks=s
c1=school(80,90)
print(c1.maths_marks)
print(c1.science_marks)
# Out:
# 80
# 90

# %%
class car():
    def __init__(self):
        self.mil=10
        self.com='BMW'
c1=car()
c2=car()
print(c1.mil,c1.com)
print(c2.mil,c2.com)
# Out:
# 8 BMW
# 10 honda

# %%
class car():
    def __init__(self):
        self.mil=10
        self.com='BMW'
c1=car()
c2=car()
c1.mil=9
c2.cmd='honda'
print(c1.mil,c1.com)
print(c2.mil,c2.com)
# Out:
# 9 BMW
# 10 BMW

# %%
class car():
    def __init__(self):
        self.mil=10
        self.com='BMW'
c1=car()
c2=car()
c1.mil=9
c2.com='honda'
print(c1.mil,c1.com)
print(c2.mil,c2.com)
# Out:
# 9 BMW
# 10 honda

# %%
class car:
    wheels = 4
    
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

c1.mil = 8
car.wheels = 5

print(c1.com, c1.mil, c1.wheels)
print(c2.com, c2.mil, c2.wheels)
# Out:
# bmw 8 5
# bmw 10 5

# %%
class student: 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
#lets create a method to calculate average of the marks 
    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(34, 47, 50)
s2 = student(89, 32, 12)

print(s1.avg())
print(s2.avg())

# we also get the value like this & rather we can print like this we also define method 
print(s1.m1)
print(s1.m2)
print(s1.m3)
print(s2.m1)
print(s2.m2)
print(s2.m3)
# Out:
# 43.666666666666664
# 44.333333333333336
# 34
# 47
# 50
# 89
# 32
# 12

# %% [markdown]
# INSTANCE METHOD

# %%
class student: 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
#lets create a method to calculate average of the marks 
    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    def get_m1(self):  # getter method (getter - get the value) GETTER only fetch the value -- ACCESOR
        return self.m1
    def set_m1(self,value): #setter method (setter - set the value) - SETTER only set the value -- MUTATOR
        self.m1 = value
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(34, 47, 50)
s2 = student(89, 32, 12)
print(s1.avg())
print(s2.avg())
# Out:
# 43.666666666666664
# 44.333333333333336

# %% [markdown]
# ### CLASS METHOD
# - instance variable can use in instance method
# - school is basically your class variable & lets create class method
# - if you work in instance then you can pass instance method
# - if you work in class then you need to pass class method

# %%
class student: 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
#lets create a method to calculate average of the marks 
    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    def info(cls):
        return cls.school 
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(34, 47, 50)
s2 = student(89, 32, 12)

print(s1.avg())
print(s2.avg())

print(s1.info())
print(s2.info())
# Out:
# 43.666666666666664
# 44.333333333333336
# nit
# nit

# %% [markdown]
# - above code we create class method which is info
# - when i print then we get the value for only one object
# - it should impact with all other object as well
# - if we have multiple object then its not good to create multiple time of class
# - thats why we need to add DECORATRO when we create multiple class

# %%
class student: 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
#lets create a method to calculate average of the marks 
    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    def info(cls):
        return cls.school 
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(34, 47, 50)
s2 = student(89, 32, 12)

print(s1.avg())
print(s2.avg())

print(student.info())
# Out:
# 43.666666666666664
# 44.333333333333336
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 23
#      20 print(s1.avg())
#      21 print(s2.avg())
# ---> 23 print(student.info())
#
# TypeError: student.info() missing 1 required positional argument: 'cls'

# %% [markdown]
# above code we get error as missing 1 argument
# ### whenever we are create class method normaly we need to special symbol
# ### that symbol we called as DECORATOR

# %%
class student: 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
#lets create a method to calculate average of the marks 
    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    @classmethod
    def getSchool(cls):
        return cls.school
    
    @staticmethod # this student class nothing to do any class 
    def info():
        print('this is student class') 
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(34, 47, 50)
s2 = student(89, 32, 12)

print(s1.avg())
print(s2.avg())

print(student.getSchool())

student.info()
# Out:
# 43.666666666666664
# 44.333333333333336
# nit
# this is student class
